# %% [markdown]
# # Test the CLI (Not Working in VSCode?)

# %%
# !py -m pyscript -b
# Out:
# ^C

# %% [markdown]
# # Test the module

# %%
import pyscript

pyscript.pys_shell(pyscript.undefined, pyscript.NOTEBOOK)
# Out:
# PyScript 1.12.11 (17 April 2026, 11:20 UTC+7)
# Python 3.14.0 (tags/v3.14.0:ebf955d, Oct  7 2025, 10:15:03) [MSC v.1944 64 bit (AMD64)]
# Type "help", "copyright", "credits" or "license" for more information.
# Type "quit", "exit" or "/exit" to exit the shell; "/clear" to clear the shell; "/clean" to clean up the namespace.
# Hello World!
# <function test at 0x000001E0147574D0>
# Traceback (most recent call last):
#   File "<pyscript-shell-2>", line 1, in <program>
#     test()
#     ^^^^^^
#   File "<pyscript-shell-1>", line 2, in test
#     error
#     ^^^^^
# NameError: name 'error' is not defined. Did you mean 'OSError'?
# 0

# %%
import pyscript

pyscript.pys_exec('print("hello world!")')
pyscript.pys_exec('code = "print(\'hello from pys_eval!\') or 1 + 1"')

print(code)

result = pyscript.pys_eval(code)
print(result)
# Out:
# hello world!
# print('hello from pys_eval!') or 1 + 1
# hello from pys_eval!
# 2

# %%
import pyscript

brainfuck = pyscript.pys_require('brainfuck.pys')

interpreter = brainfuck.BFInterpreter(
    '++++++++[>++++[>++>+++>+++>+<<<<-]>+>+>->>+[<]<-]>>.>---.+++++++..+++.>>.<-.<.+++.------.--------.>>+.>++.'
)

interpreter.start()

while interpreter.step():
    pass

interpreter.stop()
# Out:
# Hello World!
