# %% [markdown]
# # PyScript Tester for Jupyter

# %% [markdown]
# ## Python Test

# %%
import pyscript

pyscript.pys_shell(pyscript.undefined, pyscript.NOTEBOOK)
# Out:
# PyScript 1.13.4 (1 September 2026, 20:00 UTC+7)
# Python 3.14.0 (tags/v3.14.0:ebf955d, Oct  7 2025, 10:15:03) [MSC v.1944 64 bit (AMD64)]
# Type "help", "copyright", "credits" or "license" for more information.
# Type "quit", "exit" or "/exit" to exit the shell; "/clear" to clear the shell; "/clean" to clean up the namespace.
# Traceback (most recent call last):
#   File "<pyscript-shell-0>", line 1
#     Hi, It's me! It's Verity!
#           ^^^^^^^^^^
# SyntaxError: invalid syntax
# 2
# 0

# %%
import pyscript

pyscript.pys_exec('''print("Hello World!");''')
pyscript.pys_exec('''code = "print('hello from pys_eval!') or 1 + 1";''')

print(code)

result = pyscript.pys_eval(code)
print(result)
# Out:
# Hello World!
# print('hello from pys_eval!') or 1 + 1
# hello from pys_eval!
# 2

# %%
import pyscript

brainfuck = pyscript.pys_require('brainfuck')

interpreter = brainfuck.BFInterpreter(
    '++++++++[>++++[>++>+++>+++>+<<<<-]>+>+>->>+[<]<-]>>.>---.+++++++..+++.>>.<-.<.+++.------.--------.>>+.>++.'
)

interpreter.start()
while interpreter.step():
    pass
interpreter.stop()
# Out:
# Hello World!

# %%
import pyscript

this = pyscript.pys_require('this')
this.s
# Out:
# "PyScript - AzzamMuhyala\n\nWork won't get done without that grind.\nDigital snake is not as fast as California.\nBig ass projects can happen with a tiny crew.\nToo much yapping makes it hard to read.\nIf it works, don't touch it.\nOptimization is key.\nCopy and paste."
